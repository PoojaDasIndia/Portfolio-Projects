# %% [markdown]
# ## The Real life Project
# #### (A Part of Big DataSet)

# %% [markdown]
# # Police DataSet
# Here ,The Data of Police Check post is given.

# %% [markdown]
# ##### This data is available as CSV file.We are going to analyze the data set using Panda DataFrame

# %%
import pandas as pd

# %%
police=pd.read_csv(r"Police Data.csv")

# %%
police.head()
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
# 2  1/23/2005     23:15           NaN             M          1972.0
# 3  2/20/2005     17:15           NaN             M          1986.0
# 4  3/14/2005     10:00           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
police.shape
# Out:
# (65535, 15)

# %%
police.describe(include="all")
# Out:
#         stop_date stop_time  country_name driver_gender  driver_age_raw  \
# count       65535     65535           0.0         61474    61481.000000
# unique       2651      1432           NaN             2             NaN
# top     1/11/2012     10:00           NaN             M             NaN
# freq           69       280           NaN         45164             NaN
# mean          NaN       NaN           NaN           NaN     1967.791106
# std           NaN       NaN           NaN           NaN      121.050106
# min           NaN       NaN           NaN           NaN        0.000000
# 25%           NaN       NaN           NaN           NaN     1965.000000
# 50%           NaN       NaN           NaN           NaN     1978.000000
# 75%           NaN       NaN           NaN           NaN     1985.000000
# max           NaN       NaN           NaN           NaN     8801.000000
#
#           driver_age driver_race violation_raw violation search_conducted  \
# ...

# %%
police.count()
# Out:
# stop_date             65535
# stop_time             65535
# country_name              0
# driver_gender         61474
# driver_age_raw        61481
# driver_age            61228
# driver_race           61475
# violation_raw         61475
# violation             61475
# search_conducted      65535
# search_type            2479
# stop_outcome          61475
# is_arrested           61475
# stop_duration         61475
# drugs_related_stop    65535
# dtype: int64

# %% [markdown]
#  #### 1 Instruction (For Data Cleaning)
# Find all the Null value or missing value,if there is any Null fill with Mean Value.

# %%
police.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
police.drop(columns ="country_name",inplace=True )

# %%
police.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested stop_duration  drugs_related_stop
# ...

# %%
police.shape
# Out:
# (65535, 14)

# %% [markdown]
# #### **Question 2- Based on Filtering and value_counts
# ### 2.For Speeding where men and women stop more  often.

# %%
police[police["violation"]=="Speeding"].driver_gender.value_counts()
# Out:
# M    25517
# F    11686
# Name: driver_gender, dtype: int64

# %% [markdown]
# #### GroupBy
# ### 3. Does gender affect who gets searched during  a stop?

# %%
police.groupby("driver_gender").search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
police["search_conducted"].value_counts()
# Out:
# False    63056
# True      2479
# Name: search_conducted, dtype: int64

# %% [markdown]
# #### Mapping + data type castng
# ### What is the mean of stop duration?

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding             False         NaN     Citation
# 1      Speeding  Speeding             False         NaN     Citation
#
#   is_arrested  stop_duration  drugs_related_stop
# 0       False            7.5               False
# 1       False            7.5               False

# %%
police["stop_duration"].value_counts()
# Out:
# 7.5000     47379
# 22.5000    11448
# 81.5625     2647
# Name: stop_duration, dtype: int64

# %%
police["stop_duration"]=police["stop_duration"].map({"0-15 Min": 7.5,"16-30 Min":22.5,"30+ Min":81.5625})
police
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
police["stop_duration"].mean()
# Out:
# nan

# %%
c=0
sum=0
for i in range(31,60):
    c=c+1
    sum=sum+i
print(sum/16)
# Out:
# 81.5625

# %% [markdown]
# #### GroupBy & Describe
# ### 4. Compare the age distribution of each vialotion?

# %%
police.groupby("violation").driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37120.0  33.262581  12.615781  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0
