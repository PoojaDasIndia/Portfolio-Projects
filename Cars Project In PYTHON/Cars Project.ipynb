# %% [markdown]
# ## The Real life Project
# #### (A Part of Big DataSet)

# %% [markdown]
# # Car DataSet
# Here ,The Data of different cars are given with their specification.

# %% [markdown]
# ##### This data is available as CSV file.We are going to analyze the data set using Panda DataFrame

# %%
import pandas as pd

# %%
car=pd.read_csv(r"Cars Data.csv")
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
car.shape
# Out:
# (432, 15)

# %%
car.describe(include="all")
# Out:
#           Make     Model   Type Origin DriveTrain      MSRP   Invoice  \
# count      428       428    428    428        428       428       428
# unique      38       425      6      3          3       410       425
# top     Toyota  C320 4dr  Sedan   Asia      Front  $29,995   $19,638
# freq        28         2    262    158        226         2         2
# mean       NaN       NaN    NaN    NaN        NaN       NaN       NaN
# std        NaN       NaN    NaN    NaN        NaN       NaN       NaN
# min        NaN       NaN    NaN    NaN        NaN       NaN       NaN
# 25%        NaN       NaN    NaN    NaN        NaN       NaN       NaN
# 50%        NaN       NaN    NaN    NaN        NaN       NaN       NaN
# 75%        NaN       NaN    NaN    NaN        NaN       NaN       NaN
# max        NaN       NaN    NaN    NaN        NaN       NaN       NaN
#
#         EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# ...

# %%
car.count()
# Out:
# Make           428
# Model          428
# Type           428
# Origin         428
# DriveTrain     428
# MSRP           428
# Invoice        428
# EngineSize     428
# Cylinders      426
# Horsepower     428
# MPG_City       428
# MPG_Highway    428
# Weight         428
# Wheelbase      428
# Length         428
# dtype: int64

# %% [markdown]
# #### 1) Instruction (For Data Cleaning)
# * Find all the Null value,if there is any Null fill with Mean Value.

# %%
car.isnull().sum()
car.head()
car.isnull().sum()
weight=car["Weight"].mean()
mpg=car["MPG_City"].mean()

# %%
car["MSRP"].fillna(car["MSRP"].mean,inplace=True)
car["Invoice"].fillna(car["Invoice"].mean,inplace=True)
car["EngineSize"].fillna(car["EngineSize"].mean,inplace=True)
car["Cylinders"].fillna(car["Cylinders"].mean,inplace=True)
car["Horsepower"].fillna(car["Horsepower"].mean,inplace=True)
car["MPG_City"].fillna(mpg,inplace=True)
car["MPG_Highway"].fillna(car["MPG_Highway"].mean,inplace=True)
car["Weight"].fillna(weight,inplace=True)
car["Wheelbase"].fillna(car["Wheelbase"].mean,inplace=True)
car["Length"].fillna(car["Length"].mean,inplace=True)
car["Make"].fillna("NOT AVALIBLE",inplace=True)
car["Model"].fillna("NOT AVALIBLE",inplace=True)
car["Origin"].fillna("NOT AVALIBLE",inplace=True)
car["DriveTrain"].fillna("NOT AVALIBLE",inplace=True)
car["Type"].fillna("NOT AVALIBLE",inplace=True)
car.isnull().sum()
# car["Weight"].head(50)
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
car
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice EngineSize Cylinders Horsepower  MPG_City MPG_Highway  Weight  \
# ...

# %% [markdown]
# **2 Question** Based  on value_counts
# * What are the different type of Make in thev dataset,and what are the count occurence Make in the data?

# %%
car["Make"].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Volkswagen       15
# Chrysler         15
# Mitsubishi       13
# Dodge            13
# Jaguar           12
# Volvo            12
# Hyundai          12
# Kia              11
# Mazda            11
# Lexus            11
# Subaru           11
# Pontiac          11
# Lincoln           9
# Buick             9
# Mercury           9
# Infiniti          8
# Saturn            8
# Suzuki            8
# GMC               8
# Cadillac          8
# Saab              7
# Acura             7
# Porsche           7
# NOT AVALIBLE      4
# Oldsmobile        3
# Jeep              3
# Land Rover        3
# Isuzu             2
# MINI              2
# Scion             2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# **3Instruction-- Filter**
# * Show all the records in Where Origin is Asia or Europe

# %%
car.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#   EngineSize Cylinders Horsepower  MPG_City MPG_Highway  Weight Wheelbase  \
# 0        3.5       6.0      265.0      17.0        23.0  4451.0     106.0
# 1        2.0       4.0      200.0      24.0        31.0  2778.0     101.0
#
#   Length
# 0  189.0
# 1  172.0

# %%
car[car["Origin"].isin(["Asia","Europe"])].head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#   EngineSize Cylinders Horsepower  MPG_City MPG_Highway  Weight Wheelbase  \
# 0        3.5       6.0      265.0      17.0        23.0  4451.0     106.0
# 1        2.0       4.0      200.0      24.0        31.0  2778.0     101.0
# 2        2.4       4.0      200.0      22.0        29.0  3230.0     105.0
# 3        3.2       6.0      270.0      20.0        28.0  3575.0     108.0
# 4        3.5       6.0      225.0      18.0        24.0  3880.0     115.0
#
#   Length
# 0  189.0
# 1  172.0
# 2  183.0
# 3  186.0
# 4  197.0

# %% [markdown]
# **4.Removing unwanted records**
# * Remove all the records(rows)  where weight is above 4000

# %%
car["Weight"].head(50)
car[~(car["Weight"]>4000)]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice EngineSize Cylinders Horsepower  MPG_City MPG_Highway  Weight  \
# ...

# %% [markdown]
# **5 Apply Function in the columns**
# * Increase all the value of "MPG_City" with 3

# %%
car["MPG_City"].head(2)
car["MPG_City"]=car["MPG_City"].apply(lambda x:x+3)
car["MPG_City"]
# Out:
# 0      20.0
# 1      27.0
# 2      25.0
# 3      23.0
# 4      21.0
#        ...
# 427    24.0
# 428    23.0
# 429    22.0
# 430    25.0
# 431    23.0
# Name: MPG_City, Length: 432, dtype: float64

# %%
car["Invoice"]
# Out:
# 0      $33,337
# 1      $21,761
# 2      $24,647
# 3      $30,299
# 4      $39,014
#          ...
# 427    $38,203
# 428    $40,083
# 429    $42,573
# 430    $24,641
# 431    $33,112
# Name: Invoice, Length: 432, dtype: object
